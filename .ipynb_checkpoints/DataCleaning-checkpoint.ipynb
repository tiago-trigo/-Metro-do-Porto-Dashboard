# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
months = ["Janeiro", "Fevereiro", "Março", "Abril", "Maio", "Junho", "Julho", "Agosto", 
          "Setembro", "Outubro", "Novembro", "Dezembro"]

years = ["2018", "2019"]

# %%
for year in years:
    for i,month in enumerate(months):
        if year in ["2019"]:
            xls = pd.ExcelFile(f"Data/Raw/{year}/{month}{year}/{i+1}. {month} {year}_ocupaçao útil_Enviado.xlsx")
        else:
            xls = pd.ExcelFile(f"Data/Raw/{year}/{month}/{i+1}. {month} {year}_ocupaçao útil_Enviado.xlsx")
        for name in xls.sheet_names[1:]:
            df = pd.read_excel(xls, name, names = ["A","B", "Distance", "PassagersAtoB", "PassagersBtoA", "PassagersTotal", 
                                                                                                "EurotramAtoB", "EurotramBtoA", "EurotramTotal", "TraintramAtoB",
                                                                                               "TraintramBtoA", "TraintramTotal", "OccupancyAtoB", "OccupancyBtoA",
                                                                                               "OccupancyTotal"], usecols = [i for i in range(1,16)])
            df = df.iloc[3:85]
            df["PassagersAtoB"] = df['PassagersAtoB'].apply(np.floor)
            df["PassagersBtoA"] = df['PassagersBtoA'].apply(np.floor)
            df["PassagersTotal"] = df['PassagersTotal'].apply(np.floor)
            df.replace("ASra da Hora", "Sra da Hora", inplace = True)
            df.replace("BSra da Hora", "Sra da Hora", inplace = True)
            df.replace("BFonte do Cuco", "Fonte do Cuco", inplace = True)
            df.replace("Verdes (B)", "Verdes", inplace = True)
            df.replace("Verdes (E)", "Verdes", inplace = True)
            df.replace("CSra da Hora", "Sra da Hora", inplace = True)
            df.replace("CFonte do Cuco", "Fonte do Cuco", inplace = True)
            df.replace("Trindade S", "Trindade",inplace = True)
            df = pd.concat([df,pd.DataFrame(["Sra da Hora", "Fonte do Cuco", df[df["A"] == "Sra da Hora"]["Distance"].iloc[0],
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersTotal"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramTotal"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyAtoB"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyBtoA"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyTotal"]))], columns = df.columns)])
            if year in ["2019"]:
                df.to_csv(f"Data/Cleaned/{year}/{month}{year}/{name}.csv")
            else:
                df.to_csv(f"Data/Cleaned/{year}/{month}/{name}.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 24
#      22 df.replace("CFonte do Cuco", "Fonte do Cuco", inplace = True)
#      23 df.replace("Trindade S", "Trindade",inplace = True)
# ---> 24 df = pd.concat([df,pd.DataFrame(["Sra da Hora", "Fonte do Cuco", df[df["A"] == "Sra da Hora"]["Distance"].iloc[0],
#      25           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersAtoB"])),
#      26           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersBtoA"])),
#      27           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersTotal"])),
#      28           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramAtoB"])),
#      29           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramBtoA"])),
#      30           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramTotal"])),
#      31           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
#      32           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramBtoA"])),
#      33           int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
#      34           float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyAtoB"])),
#      35           float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyBtoA"])),
#      36           float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyTotal"]))], columns = df.columns)])
#      37 if year in ["2019"]:
#      38     df.to_csv(f"Data/Cleaned/{year}/{month}{year}/{name}.csv")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
#     777     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:349, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     344 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     345 index, columns = _get_axes(
#     346     values.shape[0], values.shape[1], index=index, columns=columns
#     347 )
# --> 349 _check_values_indices_shape_match(values, index, columns)
#     351 if typ == "array":
#     353     if issubclass(values.dtype.type, str):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (15, 1), indices imply (15, 15)

# %%
df6 = pd.read_csv("Data/Cleaned/2018/Abril/Média 6h-7h.csv")
df7 = pd.read_csv("Data/Cleaned/2018/Abril/Média 7h-8h.csv")
df8 = pd.read_csv("Data/Cleaned/2018/Abril/Média 8h-9h.csv")
df9 = pd.read_csv("Data/Cleaned/2018/Abril/Média 9h-10h.csv")
df10 = pd.read_csv("Data/Cleaned/2018/Abril/Média 10h-11h.csv")
df11 = pd.read_csv("Data/Cleaned/2018/Abril/Média 11h-12h.csv")
df12 = pd.read_csv("Data/Cleaned/2018/Abril/Média 12h-13h.csv")
df13 = pd.read_csv("Data/Cleaned/2018/Abril/Média 13h-14h.csv")
df14 = pd.read_csv("Data/Cleaned/2018/Abril/Média 14h-15h.csv")
df15 = pd.read_csv("Data/Cleaned/2018/Abril/Média 15h-16h.csv")
df16 = pd.read_csv("Data/Cleaned/2018/Abril/Média 16h-17h.csv")
df17 = pd.read_csv("Data/Cleaned/2018/Abril/Média 17h-18h.csv")
df18 = pd.read_csv("Data/Cleaned/2018/Abril/Média 18h-19h.csv")
df19 = pd.read_csv("Data/Cleaned/2018/Abril/Média 19h-20h.csv")
df20 = pd.read_csv("Data/Cleaned/2018/Abril/Média 20h-21h.csv")
df21 = pd.read_csv("Data/Cleaned/2018/Abril/Média 21h-22h.csv")
df22 = pd.read_csv("Data/Cleaned/2018/Abril/Média 22h-23h.csv")
df23 = pd.read_csv("Data/Cleaned/2018/Abril/Média 23h-0h.csv")

dataset_list = [f"df{i}" for i in range(6,24)]

# %%
occupancy = []
tramtrains = []
eurotrams = []
AtoB = []
BtoA = []

A = "Lapa"
B = "Trindade"

for dataset in dataset_list:
    dataset = eval(dataset)
    
    data = dataset[(dataset["A"] == A) & (dataset["B"] == B)]
    
    if data.empty:
        data = dataset[(dataset["A"] == B) & (dataset["B"] == A)]
        

    occupancy.append(float(data["OccupancyTotal"]))
    tramtrains.append(float(data["TraintramTotal"]))
    eurotrams.append(float(data["EurotramTotal"]))


print(tramtrains)
plt.bar([i for i in range(6,24)],occupancy, align = "edge")
plt.show()
plt.bar([i for i in range(6,24)],tramtrains, align = "edge")
plt.show()
plt.bar([i for i in range(6,24)],np.array(tramtrains) + np.array(eurotrams), align = "edge")
plt.show()
# Out:
# [280.0, 474.0, 514.0, 507.0, 505.0, 486.0, 539.0, 480.0, 512.0, 507.0, 511.0, 485.0, 503.0, 507.0, 283.0, 229.0, 161.0, 159.0]

# %%
print(tramtrains)
# Out:
# [280.0, 474.0, 514.0, 507.0, 505.0, 486.0, 539.0, 480.0, 512.0, 507.0, 511.0, 485.0, 503.0, 507.0, 283.0, 229.0, 161.0, 159.0]

# %%
df = pd.read_csv("Data/Cleaned/2018/Abril/Média Mensal.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pandas.set_option('display.max_rows', None)
#       2 df8
#
# NameError: name 'pandas' is not defined

# %%
lista = []

for i in range(len(df[df["A"] == "Sra da Hora"]["B"])):
    lista.append(df[df["A"] == "Sra da Hora"]["B"].iloc[i])

# %%
df8_OccAB = df8[["A", "B", "OccupancyAtoB"]]
df8_OccBA = df8[["A", "B", "OccupancyBtoA"]]
col_list = list(df8_OccBA)
col_list[0], col_list[1] = col_list[1], col_list[0]
df8_OccBA.columns = col_list
df8_OccAB = df8_OccAB.rename(columns = {"OccupancyAtoB" : "Occupancy"})
df8_OccBA = df8_OccBA.rename(columns = {"OccupancyBtoA" : "Occupancy"})
df_occupancy_morning_peak = pd.concat([df8_OccAB, df8_OccBA]).sort_values(by = ["Occupancy"]).tail(10)

# %%
df18_OccAB = df18[["A", "B", "OccupancyAtoB"]]
df18_OccBA = df18[["A", "B", "OccupancyBtoA"]]

col_list = list(df18_OccBA)
col_list[0], col_list[1] = col_list[1], col_list[0]
df18_OccBA.columns = col_list

df18_OccAB = df18_OccAB.rename(columns = {"OccupancyAtoB" : "Occupancy"})
df18_OccBA = df18_OccBA.rename(columns = {"OccupancyBtoA" : "Occupancy"})

df_occupancy_evening_peak = pd.concat([df18_OccAB, df18_OccBA]).sort_values(by = ["Occupancy"]).tail(10)

# %%
df_morning_PassAB = df_morning[["A", "B", "PassagersAtoB"]]
df_morning_PassBA = df_morning[["A", "B", "PassagersBtoA"]]
col_list = list(df_morning_PassBA)
col_list[0], col_list[1] = col_list[1], col_list[0]
df_morning_PassBA.columns = col_list
df_morning_PassAB = df_morning_PassAB.rename(columns = {"A": "Station A", "B": "Station B", "PassagersAtoB" : "Number of passagers"})
df_morning_PassBA = df_morning_PassBA.rename(columns = {"A": "Station A", "B": "Station B", "PassagersBtoA" : "Number of passagers"})
df_passagers_morning_peak = pd.concat([df_morning_PassAB, df_morning_PassBA]).sort_values(by = ["Number of passagers"], ascending = False).head(10).reset_index(drop = True)
df_passagers_morning_peak.index = np.arange(1, len(df_passagers_morning_peak) + 1)
df_passagers_morning_peak["Number of passagers"] = np.round(df_passagers_morning_peak["Number of passagers"])

df_evening_PassAB = df_evening[["A", "B", "PassagersAtoB"]]
df_evening_PassBA = df_evening[["A", "B", "PassagersBtoA"]]
col_list = list(df_evening_PassBA)
col_list[0], col_list[1] = col_list[1], col_list[0]
df_evening_PassBA.columns = col_list
df_evening_PassAB = df_evening_PassAB.rename(columns = {"A": "Station A", "B": "Station B", "PassagersAtoB" : "Number of passagers"})
df_evening_PassBA = df_evening_PassBA.rename(columns = {"A": "Station A", "B": "Station B", "PassagersBtoA" : "Number of passagers"})
df_passagers_evening_peak = pd.concat([df_evening_PassAB, df_evening_PassBA]).sort_values(by = ["Number of passagers"], ascending = False).head(10).reset_index(drop = True)
df_passagers_evening_peak.index = np.arange(1, len(df_passagers_evening_peak) + 1)
df_passagers_evening_peak["Number of passagers"] = np.round(df_passagers_evening_peak["Number of passagers"])

# %%
pd.set_option('display.max_rows', None)
df8
# Out:
#     Unnamed: 0                   A                   B  Distance  \
# 0            3            Fânzeres          Venda Nova    440.45
# 1            4          Venda Nova            Carreira    583.47
# 2            5            Carreira              Baguim    786.02
# 3            6              Baguim           Campainha    751.70
# 4            7           Campainha           Rio Tinto    859.99
# 5            8           Rio Tinto              Levada    452.83
# 6            9              Levada         Nau Vitória   1111.62
# 7           10         Nau Vitória              Nasoni    499.02
# 8           11              Nasoni            Contumil    650.00
# 9           12            Contumil   Estádio do Dragão    619.19
# 10          13   Estádio do Dragão            Campanhã   1166.02
# 11          14            Campanhã            Heroismo    950.92
# 12          15            Heroismo        24 de Agosto    571.90
# 13          16        24 de Agosto              Bolhão    680.44
# 14          17              Bolhão            Trindade    451.80
# 15          18            Trindade                Lapa    857.43
# 16          19                Lapa  Carolina Michaelis    460.97
# 17          20  Carolina Michaelis      Casa da Música    627.48
# 18          21      Casa da Música             Francos    871.87
# 19          22             Francos             Ramalde    965.03
# 20          23             Ramalde                Viso    621.15
# 21          24                Viso          Sete Bicas    743.81
# 22          25          Sete Bicas         Sra da Hora    674.50
# 23          26         Sra da Hora       Vasco da Gama    824.48
# 24          27       Vasco da Gama      Estádio do Mar    661.60
# 25          28      Estádio do Mar       Pedro Hispano    786.97
# 26          29       Pedro Hispano      Parque de Real    656.68
# 27          30      Parque de Real       C. Matosinhos    723.67
# 28          31       C. Matosinhos      Matosinhos Sul    616.61
# 29          32      Matosinhos Sul        Brito Capelo    535.72
# 30          33        Brito Capelo             Mercado    487.53
# 31          34             Mercado   Sr. de Matosinhos    708.96
# 32          35         Sra da Hora       Fonte do Cuco    687.03
# 33          36       Fonte do Cuco            Custoias    689.20
# 34          37            Custoias            Esposade   1779.24
# 35          38            Esposade            Crestins   2035.56
# 36          39            Crestins              Verdes    591.82
# 43       0.150974       0.329418        0.243331
# 44       0.147887       0.306546        0.230576
# 45       0.148692       0.309791        0.235480
# 46       0.122911       0.280847        0.203132
# 47       0.124056       0.277688        0.202091
# 48       0.123818       0.274705        0.200459
# 49       0.121348       0.274503        0.201929
# 50       0.072055       0.212419        0.149013
# 51       0.061165       0.209256        0.141803
# 52       0.045072       0.155117        0.100094
# 53       0.043209       0.145618        0.094413
# 54       0.262873       0.554287        0.406624
# 55       0.258011       0.546328        0.397982
# 56       0.253169       0.518075        0.381775
# 57       0.256236       0.488565        0.369026
# 58       0.256091       0.359389        0.312818
# 59       0.257084       0.386895        0.322980
# 60       0.239495       0.284937        0.262430
# 61       0.117228       0.140254        0.128861
# 62       0.089083       0.137581        0.113841
# 63       0.069239       0.134631        0.102361
# 64       0.049263       0.062625        0.056007
# 65       0.365606       0.056418        0.207499
# 66       0.468193       0.099957        0.291855
# 67       0.672135       0.176376        0.427172
# 68       0.767423       0.213255        0.484813
# 69       0.859755       0.224194        0.535708
# 70       0.818681       0.253237        0.546312
# 71       0.945239       0.386307        0.666588
# 72       0.911509       0.447204        0.674050
# 73       0.703683       0.411344        0.559572
# 74       0.696735       0.404263        0.552190
# 75       0.589534       0.336343        0.462570
# 76       0.549149       0.257612        0.400838
# 77       0.529762       0.211354        0.365875
# 78       0.364224       0.185143        0.274943
# 79       0.122166       0.154568        0.138414
# 80       0.142163       0.261810        0.204108
# 81       0.108293       0.240424        0.176701

# %%
print(["Sra da Hora", "Fonte do Cuco", df[df["A"] == "Sra da Hora"]["Distance"].iloc[0],
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersTotal"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramTotal"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyAtoB"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyBtoA"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyTotal"]))])
# Out:
# ['Sra da Hora', 'Fonte do Cuco', 824.48, 266331, 293673, 560004, 2525, 2563, 5088, 3827, 3810, 3827, 0.1817705259079638, 0.19757448552615878, 0.18972104478517965]

# %%
pd.DataFrame(["Sra da Hora", "Fonte do Cuco", df[df["A"] == "Sra da Hora"]["Distance"].iloc[0],
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersTotal"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramTotal"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyAtoB"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyBtoA"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyTotal"]))], columns = df.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 pd.DataFrame(["Sra da Hora", "Fonte do Cuco", df[df["A"] == "Sra da Hora"]["Distance"].iloc[0],
#       2                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersAtoB"])),
#       3                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersBtoA"])),
#       4                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersTotal"])),
#       5                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramAtoB"])),
#       6                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramBtoA"])),
#       7                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramTotal"])),
#       8                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
#       9                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramBtoA"])),
#      10                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
#      11                       float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyAtoB"])),
#      12                       float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyBtoA"])),
#      13                       float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyTotal"]))], columns = df.columns)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
#     777     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:349, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     344 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     345 index, columns = _get_axes(
#     346     values.shape[0], values.shape[1], index=index, columns=columns
#     347 )
# --> 349 _check_values_indices_shape_match(values, index, columns)
#     351 if typ == "array":
#     353     if issubclass(values.dtype.type, str):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (15, 1), indices imply (15, 15)

# %%
df.columns
# Out:
# Index(['A', 'B', 'Distance', 'PassagersAtoB', 'PassagersBtoA',
#        'PassagersTotal', 'EurotramAtoB', 'EurotramBtoA', 'EurotramTotal',
#        'TraintramAtoB', 'TraintramBtoA', 'TraintramTotal', 'OccupancyAtoB',
#        'OccupancyBtoA', 'OccupancyTotal'],
#       dtype='object')

# %%
["Sra da Hora", "Fonte do Cuco", df[df["A"] == "Sra da Hora"]["Distance"].iloc[0],
 int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersAtoB"])),
int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersBtoA"])),
int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersTotal"])),
int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramTotal"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramBtoA"])),
                      int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyAtoB"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyBtoA"])),
                      float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyTotal"]))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 13
#       1 ["Sra da Hora", "Fonte do Cuco", df[df["A"] == "Sra da Hora"]["Distance"].iloc[0],
#       2                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersAtoB"])),
#       3                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersBtoA"])),
#       4                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["PassagersTotal"])),
#       5                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramAtoB"])),
#       6                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramBtoA"])),
#       7                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["EurotramTotal"])),
#       8                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
#       9                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramBtoA"])),
#      10                       int(np.sum(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["TraintramAtoB"])),
#      11                       float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyAtoB"])),
#      12                       float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyBtoA"])),
# ---> 13                       float(np.average(df[(df["A"] == "Sra da Hora") & (df["B"] == "Fonte do Cuco")]["OccupancyTotal"]))].T
#
# AttributeError: 'list' object has no attribute 'T'
